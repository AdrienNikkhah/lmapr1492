# %%
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter
from pymatgen.analysis.diffraction.xrd import XRDCalculator
from matplotlib import pyplot as plt
from tabulate import tabulate

cle_api="rdmkQ122BgAvNKpjopTO"
id_mp="mp-665"
with MPRester(cle_api) as l:
    structure=l.get_structure_by_material_id(id_mp)
    f=CifWriter(structure)
    f.write_file('structure.cif')
    analyzer=SpacegroupAnalyzer(structure).get_primitive_standard_structure()
xrd = XRDCalculator(wavelength = 1.54060)
motif_xrd= xrd.get_pattern(analyzer,scaled=True)
pics=[0,1,2]
k=0
l=1
while k<len(pics):
    print("pic de diffraction numéro",l)
    print(motif_xrd.hkls[k][0]['hkl'])
    print("Intensité =", motif_xrd.y[k], " 'mise à l'échelle: 100' ")
    print("2\u03B8(°) =", motif_xrd.x[k],"°")
    print("\n")
    l+=1
    k+=1
xrd.show_plot(analyzer)
# Out:
# pic de diffraction numéro 1
# (0, 0, 0, 1)
# Intensité = 73.66553003717887  'mise à l'échelle: 100'
# 2θ(°) = 12.810612527988443 °
#
#
# pic de diffraction numéro 2
# (0, 0, 0, 2)
# Intensité = 0.9501415299117701  'mise à l'échelle: 100'
# 2θ(°) = 25.784931174660073 °
#
#
# pic de diffraction numéro 3
# (1, 0, -1, 0)
# Intensité = 3.4395805084499576  'mise à l'échelle: 100'
# 2θ(°) = 26.551932790931534 °
